# %% [markdown]
# <a href="https://colab.research.google.com/github/ebaad4000/python/blob/main/LAB_07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
#visualise
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline

pokemon=pd.read_csv('/content/pokemon.csv')

print(pokemon.shape)
pokemon.head()
# Out:
# (807, 14)
#    id  identifier  generation_id  height  weight  base_experience type_1  \
# 0   1   bulbasaur              1     0.7     6.9               64  grass
# 1   2     ivysaur              1     1.0    13.0              142  grass
# 2   3    venusaur              1     2.0   100.0              236  grass
# 3   4  charmander              1     0.6     8.5               62   fire
# 4   5  charmeleon              1     1.1    19.0              142   fire
#
#    type_2  hp  attack  defense  speed  special-attack  special-defense
# 0  poison  45      49       49     45              65               65
# 1  poison  60      62       63     60              80               80
# 2  poison  80      82       83     80             100              100
# 3     NaN  39      52       43     65              60               50
# 4     NaN  58      64       58     80              80               65

# %%
#remove nan values
pokemon.dropna(axis=0, inplace=True)

# %%
pokemon.head()
# Out:
#     id  identifier  generation_id  height  weight  base_experience type_1  \
# 0    1   bulbasaur              1     0.7     6.9               64  grass
# 1    2     ivysaur              1     1.0    13.0              142  grass
# 2    3    venusaur              1     2.0   100.0              236  grass
# 5    6   charizard              1     1.7    90.5              240   fire
# 11  12  butterfree              1     1.1    32.0              178    bug
#
#     type_2  hp  attack  defense  speed  special-attack  special-defense
# 0   poison  45      49       49     45              65               65
# 1   poison  60      62       63     60              80               80
# 2   poison  80      82       83     80             100              100
# 5   flying  78      84       78    100             109               85
# 11  flying  60      45       50     70              90               80

# %%
pokemon['generation_id'].value_counts()
# Out:
# 5    74
# 1    67
# 3    66
# 7    55
# 4    53
# 2    49
# 6    41
# Name: generation_id, dtype: int64

# %%
pokemon.isnull().sum()
# Out:
# id                 0
# identifier         0
# generation_id      0
# height             0
# weight             0
# base_experience    0
# type_1             0
# type_2             0
# hp                 0
# attack             0
# defense            0
# speed              0
# special-attack     0
# special-defense    0
# dtype: int64

# %%
#univariate Eploration of Data

pokemon['generation_id'].value_counts()
# Out:
# 5    156
# 1    151
# 3    135
# 4    107
# 2    100
# 7     86
# 6     72
# Name: generation_id, dtype: int64

# %%
sb.countplot(data=pokemon, x='generation_id')
# Out:
# <Axes: xlabel='generation_id', ylabel='count'>

# %%
sb.color_palette()
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
base_color = sb.color_palette()[3]

# %%
sb.countplot(data= pokemon, x= 'generation_id', color = base_color)
# Out:
# <Axes: xlabel='generation_id', ylabel='count'>

# %%
pokemon['generation_id'].value_counts()
# Out:
# 5    156
# 1    151
# 3    135
# 4    107
# 2    100
# 7     86
# 6     72
# Name: generation_id, dtype: int64

# %%
gen_order = pokemon['generation_id'].value_counts().index
gen_order
# Out:
# Int64Index([5, 1, 3, 7, 4, 2, 6], dtype='int64')

# %%
pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 405 entries, 0 to 805
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               405 non-null    int64
#  1   identifier       405 non-null    object
#  2   generation_id    405 non-null    int64
#  3   height           405 non-null    float64
#  4   weight           405 non-null    float64
#  5   base_experience  405 non-null    int64
#  6   type_1           405 non-null    object
#  7   type_2           405 non-null    object
#  8   hp               405 non-null    int64
#  9   attack           405 non-null    int64
#  10  defense          405 non-null    int64
#  11  speed            405 non-null    int64
#  12  special-attack   405 non-null    int64
#  13  special-defense  405 non-null    int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 47.5+ KB

# %%
#make the bar in order
sb.countplot(data=pokemon, x='generation_id', color=base_color, order=gen_order);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-91b3fe73b5c5> in <cell line: 2>()
#       1 #make the bar in order
# ----> 2 sb.countplot(data=pokemon, x='generation_id', color=base_color, order=gen_order);
#       3
#
# NameError: name 'base_color' is not defined

# %%
#code for the pie chart generation_id above bar chart
sorted_counts = pokemon['generation_id'] .value_counts()
plt.pie(sorted_counts, labels = sorted_counts.index, startangle=90,
     counterclock = False
        );
        plt.axis('square');
# Out:
#   File "<ipython-input-31-4f5b4a921a0a>", line 6
#     plt.axis('square');
#     ^
# IndentationError: unexpected indent

# %%
plt.hist(data=pokemon, x='speed')
# Out:
# (array([ 31.,  93., 163., 159., 128., 115.,  81.,  26.,   6.,   5.]),
#  array([  5. ,  20.5,  36. ,  51.5,  67. ,  82.5,  98. , 113.5, 129. ,
#         144.5, 160. ]),
#  <BarContainer object of 10 artists>)

# %%
bins=np.arange(0, pokemon['speed'].max()+5, 5)#start
plt.hist(data=pokemon, x='speed', bins=bins);

# %%
pokemon['type_1'].value_counts()
# Out:
# bug         54
# water       53
# grass       40
# normal      40
# rock        35
# fire        23
# dark        20
# steel       20
# poison      18
# ghost       18
# psychic     18
# ground      17
# dragon      15
# electric    12
# ice         11
# fighting     7
# fairy        2
# flying       2
# Name: type_1, dtype: int64

# %%
type_order=pokemon['type_1'].value_counts().index
sb.countplot(data=pokemon, x='type_1', color=base_color, order=type_order);

# %%
type_order=pokemon['type_1'].value_counts().index
sb.countplot(data=pokemon, y='type_1', color=base_color, order=type_order);

# %% [markdown]
# Pie Charts
# A pie chart is a common univariate plot type that is used to depict relative frequencies for levels of a categorical variable. Frequencies in a pie chart are depicted as wedges drawn on a circle: the larger the angle or area, the more common the categorical value taken.

# %%
pokemon['generation_id'].value_counts()
# Out:
# 5    74
# 1    67
# 3    66
# 7    55
# 4    53
# 2    49
# 6    41
# Name: generation_id, dtype: int64

# %%
# code for the pie chart generation_id above bar chart
sorted_counts = pokemon['generation_id'].value_counts()
plt.pie(sorted_counts, labels = sorted_counts.index, startangle = 90,
        counterclock = False);
plt.axis('square');

# %% [markdown]
# Histograms
# A histogram is used to plot the distribution of a numeric variable. It's the quantitative version of the bar chart. However, rather than plot one bar for each unique numeric value, values are grouped into continuous bins, and one bar for each bin is plotted depicting the number. For instance, using the default settings for matplotlib's hist function:

# %%
pokemon.info()

# %%
pokemon['speed'].head()

# %%
plt.hist(data=pokemon, x='speed');
#matplotlib by default make 10 bins of values

# %%
bins=np.arange(0, pokemon['speed'].max()+5, 5) # start, end, and step size
plt.hist(data=pokemon, x='speed', bins=bins

# %%
sb.displot(pokemon['speed']);

# %%
bins=np.arange(0, pokemon['height'].max()+0.5, 0.5) # start, end, and step size
plt.hist(data=pokemon, x='height', bins=bins);

# %%
bins=np.arange(0, pokemon['height'].max()+0.2, 0.2) # start, end, and step size
plt.hist(data=pokemon, x='height', bins=bins);
plt.xlim(0,6);

# %% [markdown]
# Scales and Transformations
# Certain data distributions will find themselves amenable to scale transformations. The most common example of this is data that follows an approximately log-normal distribution. This is data that, in their natural units, can look highly skewed: lots of points with low values, with a very long tail of data points with large values. However, after applying a logarithmic transform to the data, the data will follow a normal distribution.

# %%
bins=np.arange(0, pokemon['weight'].max()+40, 40) # start, end, and step size
plt.hist(data=pokemon, x='weight', bins=bins);
# plt.xscale('log')

# %%
bins=np.arange(0, pokemon['weight'].max()+40, 40) # start, end, and step size
plt.hist(data=pokemon, x='weight', bins=bins);
plt.xscale('log');

# %%
pokemon['weight'].describe()
#min value is 0.100000 and max value is max      999.900000

# %%
np.log10(pokemon['weight'].describe())
#min value is -1 and max value is approximately 3

# %%
bins = 10 ** np.arange(-1, 3+0.1, 0.1) # start, end, and step size
plt.hist(data=pokemon, x='weight', bins=bins);
plt.xscale('log');

# %%
bins = 10 ** np.arange(-1, 3+0.1, 0.1) # start, end, and step size
ticks=[0.1, 1, 3, 10, 30, 100, 300, 1000]
labels = ['{}'.format(v) for v in ticks]
plt.hist(data=pokemon, x='weight', bins=bins);
plt.xscale('log');
plt.xticks(ticks, labels),

# %% [markdown]
# Bivariate Exploration of Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#load dataset
fuel_econ = pd.read_csv('fuel-econ.csv')
fuel_econ.head(6)
# Out:
#       id        make           model  year           VClass  \
# 0  32204      Nissan            GT-R  2013  Subcompact Cars
# 1  32205  Volkswagen              CC  2013     Compact Cars
# 2  32206  Volkswagen              CC  2013     Compact Cars
# 3  32207  Volkswagen      CC 4motion  2013     Compact Cars
# 4  32208   Chevrolet  Malibu eAssist  2013     Midsize Cars
# 5  32209       Lexus          GS 350  2013     Midsize Cars
#
#                drive              trans          fuelType  cylinders  displ  \
# 0    All-Wheel Drive    Automatic (AM6)  Premium Gasoline          6    3.8
# 1  Front-Wheel Drive  Automatic (AM-S6)  Premium Gasoline          4    2.0
# 2  Front-Wheel Drive     Automatic (S6)  Premium Gasoline          6    3.6
# 3    All-Wheel Drive     Automatic (S6)  Premium Gasoline          6    3.6
# 4  Front-Wheel Drive     Automatic (S6)  Regular Gasoline          4    2.4
# 5   Rear-Wheel Drive     Automatic (S6)  Premium Gasoline          6    3.5
#
# ...

# %% [markdown]
# Scatterplots
# If we want to inspect the relationship between two numeric variables, the standard choice of plot is the scatterplot. In a scatterplot, each data point is plotted individually as a point, its x-position corresponding to one feature value and its y-position corresponding to the second. One basic way of creating a scatterplot is through Matplotlib's scatter function:

# %%
plt.scatter(data=fuel_econ, x='displ',y='comb')
plt.xlabel('Displacement')
plt.ylabel('Combined Fuel Efficiency')

# %%
sns.regplot(data=fuel_econ, x='displ',y='comb')
plt.xlabel('Displacement')
plt.ylabel('Combined Fuel Efficiency')

# %%
sns.regplot(data=fuel_econ, x='year',y='comb');

# %% [markdown]
# Overplotting, Transparency, and Jitter
# If we have a very large number of points to plot or our numeric variables are discrete-valued, then it is possible that using a scatterplot straightforwardly will not be informative. The visualization will suffer from overplotting, where the high amount of overlap in points makes it difficult to see the actual relationship between the plotted variables.

# %%
#add jitter
sns.regplot(data=fuel_econ, x='year',y='comb',x_jitter=0.3);

# %%
#Add Transparency
sns.regplot(data=fuel_econ, x='year',y='comb',x_jitter=0.3,
           scatter_kws={'alpha': 1/20});

#darker area shows the overlap of the data ; this is area Where the main bulk of the data lies.

# %% [markdown]
# Heat Maps
# A heat map is a 2-d version of the histogram that can be used as an alternative to a scatterplot. Like a scatterplot, the values of the two numeric variables to be plotted are placed on the plot axes. Similar to a histogram, the plotting area is divided into a grid and the number of points in each grid rectangle is added up. Since there won't be room for bar heights, counts are indicated instead by grid cell color. A heat map can be implemented with Matplotlib's hist2d function.

# %%
plt.hist2d(data=fuel_econ, x='displ',y='comb')
plt.colorbar()
plt.xlabel('Displacement')
plt.ylabel('Combined Fuel Efficiency')
# Out:
# Text(0, 0.5, 'Combined Fuel Efficiency')

# %%
plt.hist2d(data=fuel_econ, x='displ',y='comb',cmin=0.5)
plt.colorbar()
plt.xlabel('Displacement')
plt.ylabel('Combined Fuel Efficiency')
# Out:
# Text(0, 0.5, 'Combined Fuel Efficiency')

# %%
plt.hist2d(data=fuel_econ, x='displ',y='comb',cmin=0.5,cmap='viridis_r')
plt.colorbar()
plt.xlabel('Displacement')
plt.ylabel('Combined Fuel Efficiency')
# Out:
# Text(0, 0.5, 'Combined Fuel Efficiency')

# %% [markdown]
# Boxplot
# A box plot is another way of showing the relationship between a numeric variable and a categorical variable. Compared to the violin plot, the box plot leans more on summarization of the data, primarily just reporting a set of descriptive statistics for the numeric values on each categorical level. A box plot can be created using seaborn's boxplot function.

# %% [markdown]
# the most common upper bound of the length is 1.5 of IQR
# Therefore max whisker length is 8.25

# %%
base_color = sns.color_palette()[0]
sns.boxplot(data=fuel_econ, x='VClass', y='comb',color=base_color)
plt.xticks(rotation=15)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-573c7f08aef4> in <cell line: 1>()
# ----> 1 base_color = sns.color_palette()[0]
#       2 sns.boxplot(data=fuel_econ, x='VClass', y='comb',color=base_color)
#       3 plt.xticks(rotation=15)
#
# NameError: name 'sns' is not defined

# %% [markdown]
# Clustered Bar Charts
# To depict the relationship between two categorical variables, we can extend the univariate bar chart seen in the previous lesson into a clustered bar chart. Like a standard bar chart, we still want to depict the count of data points in each group, but each group is now a combination of labels on two variables. So we want to organize the bars into an order that makes the plot easy to interpret. In a clustered bar chart, bars are organized into clusters based on levels of the first variable, and then bars are ordered consistently across the second variable within each cluster. This is easiest to see with an example, using seaborn's countplot function. To take the plot from univariate to bivariate, we add the second variable to be plotted under the "hue" argument:

# %%
fuel_econ['trans_type'] = fuel_econ['trans'].apply(lambda x: x.split()[0])

# %%
fuel_econ['trans'].head()
# Out:
# 0      Automatic (AM6)
# 1    Automatic (AM-S6)
# 2       Automatic (S6)
# 3       Automatic (S6)
# 4       Automatic (S6)
# Name: trans, dtype: object

# %%
ct_counts = fuel_econ.groupby(['VClass','trans_type']).size()
ct_counts = ct_counts.reset_index(name='count')
ct_counts.pivot(index='VClass',columns='trans_type',values='count')
# Out:
# trans_type        Automatic  Manual
# VClass
# Compact Cars            784     338
# Large Cars              605      20
# Midsize Cars            989     199
# Minicompact Cars        188     133
# Subcompact Cars         502     171

# %%
sns.countplot(data=fuel_econ,x='VClass',hue='trans_type')
plt.xticks(rotation=15)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-b11ff5bc2331> in <cell line: 1>()
# ----> 1 sns.countplot(data=fuel_econ,x='VClass',hue='trans_type')
#       2 plt.xticks(rotation=15)
#       3
#
# NameError: name 'sns' is not defined

# %%
bins = np.arange(12,58+2,2)
g = sns.FacetGrid(data=fuel_econ,col='VClass',col_wrap=3)
g.map(plt.hist,'comb',bins=bins);

# %%
base_color = sns.color_palette()[0]
sns.barplot(data=fuel_econ,x='VClass',y='comb',color=base_color)
plt.xticks(rotation=15)
plt.ylabel('Average Fuel Efficiency')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-0ce3c182b626> in <cell line: 1>()
# ----> 1 base_color = sns.color_palette()[0]
#       2 sns.barplot(data=fuel_econ,x='VClass',y='comb',color=base_color)
#       3 plt.xticks(rotation=15)
#       4 plt.ylabel('Average Fuel Efficiency')
#       5
#
# NameError: name 'sns' is not defined

# %% [markdown]
# Line plot
# The line plot is a fairly common plot type that is used to plot the trend of one numeric variable against values of a second variable. In contrast to a scatterplot, where all data points are plotted, in a line plot, only one point is plotted for every unique x-value or bin of x-values (like a histogram). If there are multiple observations in an x-bin, then the y-value of the point plotted in the line plot will be a summary statistic (like mean or median) of the data in the bin. The plotted points are connected with a line that emphasizes the sequential or connected nature of the x-values.

# %%
sns.pointplot(data = fuel_econ, x = 'VClass', y = 'comb')
plt.ylabel('Average Fuel Efficiency')
plt.xticks(rotation=15)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-e5d8072925d0> in <cell line: 1>()
# ----> 1 sns.pointplot(data = fuel_econ, x = 'VClass', y = 'comb')
#       2 plt.ylabel('Average Fuel Efficiency')
#       3 plt.xticks(rotation=15)
#       4
#
# NameError: name 'sns' is not defined

# %% [markdown]
# # Lab 7 Task

# %%
#store data
import numpy as np
import pandas as pd
#visualize
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline

# %%
diamond=pd.read_csv('/content/Diamonds Prices2022.csv')

# %%
print(diamond.shape)
diamond.head(10)
# Out:
# (53943, 11)
#    Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0           1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1           2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2           3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3           4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4           5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# 5           6   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94
# 6           7   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95
# 7           8   0.26  Very Good     H     SI1   61.9   55.0    337  4.07
# 8           9   0.22       Fair     E     VS2   65.1   61.0    337  3.87
# 9          10   0.23  Very Good     H     VS1   59.4   61.0    338  4.00
#
#       y     z
# 0  3.98  2.43
# 1  3.84  2.31
# 2  4.07  2.31
# 3  4.23  2.63
# 4  4.35  2.75
# 5  3.96  2.48
# 6  3.98  2.47
# 7  4.11  2.53
# ...

# %%
diamond.isnull().sum()
# Out:
# Unnamed: 0    0
# carat         0
# cut           0
# color         0
# clarity       0
# depth         0
# table         0
# price         0
# x             0
# y             0
# z             0
# dtype: int64

# %%
diamond['cut'].value_counts()
# Out:
# Ideal        21551
# Premium      13793
# Very Good    12083
# Good          4906
# Fair          1610
# Name: cut, dtype: int64

# %% [markdown]
# # Univariate Exploration of Data
# # Bar Chart
# A bar chart is used to depict the distribution of a categorical variable. In a bar chart, each level of the categorical variable is depicted with a bar, whose height indicates the frequency of data points that take on that level. A basic bar chart of frequencies can be created through the use of seaborn's countplot function:

# %%
#generation_id are categorical
#let's plot it
sb.countplot(data=diamond, x='price');
# ; supress the object information

# %%
#let's use a one colour
sb.color_palette()
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
#let's use a one colour
base_color=sb.color_palette()[0]

# %%
sb.countplot(data=diamond, x='price', color=base_color);

# %%
diamond['price'].value_counts()
# Out:
# 605      132
# 802      127
# 625      126
# 828      125
# 776      124
#         ...
# 8816       1
# 14704      1
# 14699      1
# 14698      1
# 9793       1
# Name: price, Length: 11602, dtype: int64

# %%
price_order=diamond['price'].value_counts().index

# %%
price_order
# Out:
# Int64Index([  605,   802,   625,   828,   776,   698,   789,   544,   666,
#               552,
#             ...
#             14719, 14692, 14717,  8815, 14711,  8816, 14704, 14699, 14698,
#              9793],
#            dtype='int64', length=11602)

# %%
#make the bar in order
sb.countplot(data=diamond, x='price', color=base_color, order=price_order);

# %%
diamond.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53943 entries, 0 to 53942
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53943 non-null  int64
#  1   carat       53943 non-null  float64
#  2   cut         53943 non-null  object
#  3   color       53943 non-null  object
#  4   clarity     53943 non-null  object
#  5   depth       53943 non-null  float64
#  6   table       53943 non-null  float64
#  7   price       53943 non-null  int64
#  8   x           53943 non-null  float64
#  9   y           53943 non-null  float64
#  10  z           53943 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 4.5+ MB

# %%
diamond['price'].value_counts()
# Out:
# 605      132
# 802      127
# 625      126
# 828      125
# 776      124
#         ...
# 8816       1
# 14704      1
# 14699      1
# 14698      1
# 9793       1
# Name: price, Length: 11602, dtype: int64

# %%
depth_order=diamond['depth'].value_counts().index
sb.countplot(data=diamond, x='depth', color=base_color, order=depth_order);

# %%
depth_order=diamond['depth'].value_counts().index
sb.countplot(data=diamond, y='depth', color=base_color, order=depth_order);

# %% [markdown]
# # Pie Charts
#  A pie chart is a common univariate plot type that is used to depict relative frequencies for levels of a categorical variable. Frequencies in a pie chart are depicted as wedges drawn on a circle: the larger the angle or area, the more common the categorical value taken.

# %%
diamond['cut'].value_counts()
# Out:
# Ideal        21551
# Premium      13793
# Very Good    12083
# Good          4906
# Fair          1610
# Name: cut, dtype: int64

# %%
# code for the pie chart generation_id above bar chart
sorted_counts = diamond['cut'].value_counts()
plt.pie(sorted_counts, labels = sorted_counts.index, startangle = 90, counterclock = False);
plt.axis('square');

# %% [markdown]
# # Histograms
# A histogram is used to plot the distribution of a numeric variable. It's the quantitative version of the bar chart. However, rather than plot one bar for each unique numeric value, values are grouped into continuous bins, and one bar for each bin is plotted depicting the number. For instance, using the default settings for matplotlib's hist function:

# %%
diamond.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53943 entries, 0 to 53942
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53943 non-null  int64
#  1   carat       53943 non-null  float64
#  2   cut         53943 non-null  object
#  3   color       53943 non-null  object
#  4   clarity     53943 non-null  object
#  5   depth       53943 non-null  float64
#  6   table       53943 non-null  float64
#  7   price       53943 non-null  int64
#  8   x           53943 non-null  float64
#  9   y           53943 non-null  float64
#  10  z           53943 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 4.5+ MB

# %%
diamond['color'].head()
# Out:
# 0    E
# 1    E
# 2    E
# 3    I
# 4    J
# Name: color, dtype: object

# %%
plt.hist(data=diamond, x='color');
#matplotlib by default make 10 bins of values

# %%
bins=np.arange(0, diamond['carat'].max()+5, 5) # start, end, and step size
plt.hist(data=diamond, x='cut', bins=bins);

# %%
sb.displot(diamond['color']);

# %%
bins=np.arange(0, diamond['carat'].max()+0.5, 0.5) # start, end, and step size
plt.hist(data=diamond, x='cut', bins=bins);

# %%
bins=np.arange(0, diamond['price'].max()+0.2, 0.2) # start, end, and step size
plt.hist(data=diamond, x='cut', bins=bins);
plt.xlim(0,6);

# %% [markdown]
# # Scales and Transformations
# Certain data distributions will find themselves amenable to scale transformations. The most common example of this is data that follows an approximately log-normal distribution. This is data that, in their natural units, can look highly skewed: lots of points with low values, with a very long tail of data points with large values. However, after applying a logarithmic transform to the data, the data will follow a normal distribution.

# %%
bins=np.arange(0, diamond['x'].max()+40, 40) # start, end, and step size
plt.hist(data=diamond, x='x', bins=bins);
# plt.xscale('log')

# %%
bins=np.arange(0, diamond['y'].max()+40, 40) # start, end, and step size
plt.hist(data=diamond, x='y', bins=bins);
plt.xscale('log');

# %%
diamond['y'].describe()
#min value is 0.100000 and max value is max      999.900000
# Out:
# count    53943.000000
# mean         5.734526
# std          1.142103
# min          0.000000
# 25%          4.720000
# 50%          5.710000
# 75%          6.540000
# max         58.900000
# Name: y, dtype: float64

# %%
np.log10(diamond['x'].describe())
#min value is -1 and max value is approximately 3
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# count    4.731935
# mean     0.758242
# std      0.049888
# min          -inf
# 25%      0.673021
# 50%      0.755875
# 75%      0.815578
# max      1.031004
# Name: x, dtype: float64

# %%
bins = 10 ** np.arange(-1, 3+0.1, 0.1) # start, end, and step size
plt.hist(data=diamond, x='color', bins=bins);
plt.xscale('log');

# %%
bins = 10 ** np.arange(-1, 3+0.1, 0.1) # start, end, and step size
ticks=[0.1, 1, 3, 10, 30, 100, 300, 1000]
labels = ['{}'.format(v) for v in ticks]
plt.hist(data=diamond, x='cut', bins=bins);
plt.xscale('log');
plt.xticks(ticks, labels),
# Out:
# (([<matplotlib.axis.XTick at 0x7bd6eb389270>,
# ...
#   [Text(0.1, 0, '0.1'),
#    Text(1.0, 0, '1'),
#    Text(3.0, 0, '3'),
#    Text(10.0, 0, '10'),
#    Text(30.0, 0, '30'),
#    Text(100.0, 0, '100'),
#    Text(300.0, 0, '300'),
#    Text(1000.0, 0, '1000')]),)

# %% [markdown]
# most common weights is between 10 and 100 with a pick around 30
#
# # Bivariate Exploration of Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#load dataset
diam = pd.read_csv('/content/Diamonds Prices2022.csv')
diam.head(6)
# Out:
#    Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0           1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1           2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2           3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3           4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4           5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# 5           6   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94
#
#       y     z
# 0  3.98  2.43
# 1  3.84  2.31
# 2  4.07  2.31
# 3  4.23  2.63
# 4  4.35  2.75
# 5  3.96  2.48

# %% [markdown]
# # Scatterplots
# If we want to inspect the relationship between two numeric variables, the standard choice of plot is the scatterplot. In a scatterplot, each data point is plotted individually as a point, its x-position corresponding to one feature value and its y-position corresponding to the second. One basic way of creating a scatterplot is through Matplotlib's scatter function:

# %%
plt.scatter(data=diam, x='price',y='carat')
plt.xlabel('PRICE')
plt.ylabel('CUTTING')
# Out:
# Text(0, 0.5, 'CUTTING')

# %%
sns.regplot(data=diam, x='price',y='carat')
plt.xlabel('PRICE')
plt.ylabel('Carat of Diamond')
# Out:
# Text(0, 0.5, 'Carat of Diamond')

# %%
sns.regplot(data=diam, x='x',y='y');

# %% [markdown]
# # Overplotting, Transparency, and Jitter
#  If we have a very large number of points to plot or our numeric variables are discrete-valued, then it is possible that using a scatterplot straightforwardly will not be informative. The visualization will suffer from overplotting, where the high amount of overlap in points makes it difficult to see the actual relationship between the plotted variables.

# %%
#add jitter
sns.regplot(data=diam, x='x',y='y',x_jitter=0.3);

# %%
#Add Transparency
sns.regplot(data=diam, x='x',y='y',x_jitter=0.3, scatter_kws={'alpha': 1/20});

#darker area shows the overlap of the data ; this is area Where the main bulk of the data lies.

# %% [markdown]
# # Heat Maps
# A heat map is a 2-d version of the histogram that can be used as an alternative to a scatterplot. Like a scatterplot, the values of the two numeric variables to be plotted are placed on the plot axes. Similar to a histogram, the plotting area is divided into a grid and the number of points in each grid rectangle is added up. Since there won't be room for bar heights, counts are indicated instead by grid cell color. A heat map can be implemented with Matplotlib's hist2d function.

# %%
plt.hist2d(data=diam, x='x',y='y')
plt.colorbar()
plt.xlabel('X')
plt.ylabel('Y')
# Out:
# Text(0, 0.5, 'Y')

# %%
plt.hist2d(data=diam, x='X',y='Y',cmin=0.5)
plt.colorbar()
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-78-8c488fd1838f> in <cell line: 1>()
# ----> 1 plt.hist2d(data=diam, x='X',y='Y',cmin=0.5)
#       2 plt.colorbar()
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in hist2d(x, y, bins, range, density, weights, cmin, cmax, data, **kwargs)
#    2667         x, y, bins=10, range=None, density=False, weights=None,
#    2668         cmin=None, cmax=None, *, data=None, **kwargs):
# -> 2669     __ret = gca().hist2d(
#    2670         x, y, bins=bins, range=range, density=density,
#    2671         weights=weights, cmin=cmin, cmax=cmax,
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1466                 args_and_kwargs.get(label_namer), auto_label)
#    1467
# -> 1468         return func(*new_args, **new_kwargs)
#    1469
# ...

# %%
plt.hist2d(data=diam, x='X',y='Y',cmin=0.5,cmap='viridis_r')
plt.colorbar()
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-79-7ce2b7842886> in <cell line: 1>()
# ----> 1 plt.hist2d(data=diam, x='X',y='Y',cmin=0.5,cmap='viridis_r')
#       2 plt.colorbar()
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in hist2d(x, y, bins, range, density, weights, cmin, cmax, data, **kwargs)
#    2667         x, y, bins=10, range=None, density=False, weights=None,
#    2668         cmin=None, cmax=None, *, data=None, **kwargs):
# -> 2669     __ret = gca().hist2d(
#    2670         x, y, bins=bins, range=range, density=density,
#    2671         weights=weights, cmin=cmin, cmax=cmax,
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1466                 args_and_kwargs.get(label_namer), auto_label)
#    1467
# -> 1468         return func(*new_args, **new_kwargs)
#    1469
# ...

# %% [markdown]
# # Boxplot
# A box plot is another way of showing the relationship between a numeric variable and a categorical variable. Compared to the violin plot, the box plot leans more on summarization of the data, primarily just reporting a set of descriptive statistics for the numeric values on each categorical level. A box plot can be created using seaborn's boxplot function.

# %% [markdown]
# ![download.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# IQR - Inter Quartile Range or box length
#
#
# the most common upper bound of the length is 1.5 of IQR
# Therefore max whisker length is 8.25

# %% [markdown]
# # Clustered Bar Charts
# To depict the relationship between two categorical variables, we can extend the univariate bar chart seen in the previous lesson into a clustered bar chart. Like a standard bar chart, we still want to depict the count of data points in each group, but each group is now a combination of labels on two variables. So we want to organize the bars into an order that makes the plot easy to interpret. In a clustered bar chart, bars are organized into clusters based on levels of the first variable, and then bars are ordered consistently across the second variable within each cluster. This is easiest to see with an example, using seaborn's countplot function. To take the plot from univariate to bivariate, we add the second variable to be plotted under the "hue" argument:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
diam['trans_type'] = diam['trans'].apply(lambda x: x.split()[0])

# %%
diam['X'].head()

# %%
ct_counts = diam.groupby(['VClass','trans_type']).size()
ct_counts = ct_counts.reset_index(name='count')
ct_counts.pivot(index='VClass',columns='trans_type',values='count')

# %%
sns.countplot(data=diam,x='price',hue='trans_type')
plt.xticks(rotation=15)

# %%
bins = np.arange(12,58+2,2)
g = sns.FacetGrid(data=diam,col='cut',col_wrap=3)
g.map(plt.hist,'comb',bins=bins);

# %%
base_color = sns.color_palette()[0]
sns.barplot(data=diam,x='cut',y='table',color=base_color)
plt.xticks(rotation=15)
plt.ylabel('Diamonds')
# Out:
# Text(0, 0.5, 'Diamonds')

# %% [markdown]
# # Line plot
# The line plot is a fairly common plot type that is used to plot the trend of one numeric variable against values of a second variable. In contrast to a scatterplot, where all data points are plotted, in a line plot, only one point is plotted for every unique x-value or bin of x-values (like a histogram). If there are multiple observations in an x-bin, then the y-value of the point plotted in the line plot will be a summary statistic (like mean or median) of the data in the bin. The plotted points are connected with a line that emphasizes the sequential or connected nature of the x-values.

# %%
sns.pointplot(data = diam, x = 'cut', y = 'table')
plt.ylabel('Diamonds')
plt.xticks(rotation=15)
# Out:
# (array([0, 1, 2, 3, 4]),
#  [Text(0, 0, 'Ideal'),
#   Text(1, 0, 'Premium'),
#   Text(2, 0, 'Good'),
#   Text(3, 0, 'Very Good'),
#   Text(4, 0, 'Fair')])
