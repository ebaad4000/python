# %% [markdown]
# <a href="https://colab.research.google.com/github/ebaad4000/python/blob/main/Decision_Tree_for_predicting_drug_types.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('/content/drug200.csv')

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

df["Drug_n"] = le.fit_transform(df["Drug"])
df.drop('Drug', axis='columns', inplace= True)

# %%
target = df.Drug_n
target
# Out:
# 0      4
# 1      2
# 2      2
# 3      3
# 4      4
#       ..
# 195    2
# 196    2
# 197    3
# 198    3
# 199    3
# Name: Drug_n, Length: 200, dtype: int64

# %%
df.head()
# Out:
#    Age Sex      BP Cholesterol  Na_to_K  Drug_n
# 0   23   F    HIGH        HIGH   25.355       4
# 1   47   M     LOW        HIGH   13.093       2
# 2   47   M     LOW        HIGH   10.114       2
# 3   28   F  NORMAL        HIGH    7.798       3
# 4   61   F     LOW        HIGH   18.043       4

# %%
df["Sex_n"] = le.fit_transform(df["Sex"])
df["BP_n"] = le.fit_transform(df["BP"])
df["Cholesterol_n"] = le.fit_transform(df["Cholesterol"])

# %%
df.drop(['Sex', 'BP', 'Cholesterol'], axis= 'columns', inplace=True)
df.head()
# Out:
#    Age  Na_to_K  Drug_n  Sex_n  BP_n  Cholesterol_n
# 0   23   25.355       4      0     0              0
# 1   47   13.093       2      1     1              0
# 2   47   10.114       2      1     1              0
# 3   28    7.798       3      0     2              0
# 4   61   18.043       4      0     1              0

# %%
inputs = df[['Age','Na_to_K','Sex_n','BP_n', 'Cholesterol_n']]

inputs.tail()
# Out:
#      Age  Na_to_K  Sex_n  BP_n  Cholesterol_n
# 195   56   11.567      0     1              0
# 196   16   12.006      1     1              0
# 197   52    9.894      1     2              0
# 198   23   14.020      1     2              1
# 199   40   11.349      0     1              1

# %%
x_test[2:5]
# Out:
#      Age  Na_to_K  Sex_n  BP_n  Cholesterol_n
# 167   57   14.216      0     2              0
# 13    74   20.942      0     1              0
# 86    51   13.597      0     2              0

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(inputs, target, test_size=0.15)

# %%
y_test[2:5]
# Out:
# 167    3
# 13     4
# 86     3
# Name: Drug_n, dtype: int64

# %%
model.predict([[19, 2.111, 1, 2, 3]])
# Out:
# array([3])

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(x_train, y_train)

model.score(x_test, y_test)
# Out:
# 1.0

# %%
y_pred = model.predict(x_test)
from sklearn.metrics import accuracy_score

accuracy_score(y_test, y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-2421e76792cc> in <cell line: 1>()
# ----> 1 y_pred = model.predict(x_test)
#       2 from sklearn.metrics import accuracy_score
#       3
#       4 accuracy_score(y_test, y_pred)
#
# NameError: name 'model' is not defined

# %%
newdf.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-c7446e2a9b2c> in <cell line: 1>()
# ----> 1 newdf.head(10)
#
# NameError: name 'newdf' is not defined

# %%
model.predict([[40,11.349,0, 1,1]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-6435fc9fa087> in <cell line: 1>()
# ----> 1 model.predict([[40,11.349,0, 1,1]])
#
# NameError: name 'model' is not defined
